# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt

from sklearn import metrics  
from sklearn.model_selection import GridSearchCV, cross_val_predict
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# import data
train_data = pd.read_csv('../data/train_data.csv')
test_data = pd.read_csv('../data/test_data.csv')

# get column names
X = train_data.drop(columns=['Grade']).columns.tolist()  # List of feature column names
y = 'Grade'  # Target column name

def cross_val(clf, train_data):
    # Get cross-validated predictions and performance report
    pred = cross_val_predict(clf, train_data[X], train_data[y], cv=5)
    cv_report = classification_report(train_data[y], pred)
    print('Cross-validation classification report')
    print(cv_report)

def fit_predict(clf, train_data, test_data):
    # train and test model
    clf.fit(train_data[X], train_data[y])
    pred = clf.predict(test_data[X])
    return clf, pred

def get_classification_report(y_test, y_pred):
    test_report = classification_report(y_test, y_pred)
    print('Test classification report')
    print(test_report)

def get_confusion_matrix(y_test, y_pred):
    labels = ['low', 'medium', 'high']
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot()
    plt.show()

def evaluate_model(clf, train_data, test_data):
    cross_val(clf, train_data)
    clf_fit, test_pred = fit_predict(clf, train_data, test_data)
    get_classification_report(test_data[y], test_pred)
    get_confusion_matrix(test_data[y], test_pred)
    return clf_fit

def plot_feature_imp(clf):
    # Get feature importances
    feature_importances = clf.feature_importances_
    
    # Create a DataFrame to display feature names with their importance scores
    importance_df = pd.DataFrame({'Feature': X, 'Importance': feature_importances})
    
    # Sort by importance (descending order)
    importance_df = importance_df.sort_values(by='Importance', ascending=True)  # Ascending for correct bar order
    
    # Create an Altair horizontal bar chart
    chart = alt.Chart(importance_df).mark_bar().encode(
        x=alt.X('Importance:Q', title='Importance Score', axis=alt.Axis(grid=False)),
        y=alt.Y('Feature:N', sort='x', title='Feature'),  # Sorting ensures highest importance at top
        color=alt.Color('Importance:Q', scale=alt.Scale(scheme='blues'))  # Color intensity based on importance
    ).properties(
        title='Feature Importance from Random Forest',
        width=600,
        height=400
    )
    
    chart.show()

# %% [markdown]
# https://scikit-learn.org/1.6/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# https://www.geeksforgeeks.org/random-forest-classifier-using-scikit-learn/
#
# Random forest classifier parameters:
# - `n_estimators` (B): number of trees in the forest
#     - default = 100
#     - generally more is better but time-consuming
# - `max_depth`: maximum depth of each tree
#     - default = None
#     - deeper trees can capture more complex patterns, but also risk overfitting
#     - experiment with values between 5 and 15, and consider lower values for smaller datasets
# - `max_features` (m): number of features considered for splitting at each node
#     - default = 'sqrt' (square root of total number of features p)
#     - adjust based on dataset size and feature importance
# - `criterion`: function used to measure split quality ('gini' or 'entropy')
#     - gini is often slightly faster, but both are similar in performance
# - `min_samples_split`: minimum samples requires to split a node
#     - default = 2
#     - higher values can prevent overfitting, too high can hinder model complexity
# - `min_samples_leaf`: minimum samples required to be at a leaf node (prediction)
#     - default = 1
# - `bootstrap`: whether to use bootstrap sampling when building trees (True or False)
#     - default = True

# %%
# default Decision Tree classifier
dt_clf = DecisionTreeClassifier(random_state=42)
dt_fit = evaluate_model(dt_clf, train_data, test_data)
plot_feature_imp(dt_fit)
# Out:
# Cross-validation classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       351
#            1       0.99      1.00      0.99       288
#            2       0.99      0.99      0.99       208
#
#     accuracy                           1.00       847
#    macro avg       0.99      0.99      0.99       847
# weighted avg       1.00      1.00      1.00       847
#
# Test classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        78
#            1       0.99      1.00      0.99        86
#            2       0.98      0.98      0.98        48
#
#     accuracy                           0.99       212
#    macro avg       0.99      0.99      0.99       212
# weighted avg       0.99      0.99      0.99       212
# alt.Chart(...)

# %%
# default RF classifier
rf_clf = RandomForestClassifier(random_state=42)
rf_fit = evaluate_model(dt_clf, train_data, test_data)
plot_feature_imp(rf_fit)
# Out:
# Cross-validation classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       351
#            1       0.99      1.00      0.99       288
#            2       0.99      0.99      0.99       208
#
#     accuracy                           1.00       847
#    macro avg       0.99      0.99      0.99       847
# weighted avg       1.00      1.00      1.00       847
#
# Test classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        78
#            1       0.99      1.00      0.99        86
#            2       0.98      0.98      0.98        48
#
#     accuracy                           0.99       212
#    macro avg       0.99      0.99      0.99       212
# weighted avg       0.99      0.99      0.99       212
# alt.Chart(...)

# %%
# Define the hyperparameter grid
param_grid = {
    'n_estimators': [5, 10, 25, 50, 75, 100], # [50, 75, 100, 125, 150],  # Number of trees
    'max_depth': [None, 1, 5, 10, 15, 20],  # Maximum depth of each tree
    'min_samples_split': [2, 3, 4], # Number of samples required to split a node
    # 'min_samples_leaf': [1, 2, 3, 4] # Number of samples required in leaf
}

# Initialize the RandomForest classifier
clf = RandomForestClassifier(random_state=42)

# Set up GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=clf,
    param_grid=param_grid,
    cv=5,
    scoring='f1_macro',  # You can change this based on your evaluation metric
    n_jobs=-1,  # Use all available processors
    verbose=1  # To see progress
)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Best parameters from GridSearchCV
print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 5}

# %%
# evaluate best estimator from grid search
best_clf = grid_search.best_estimator_
best_fit = evaluate_model(best_clf, train_data, test_data)
plot_feature_imp(best_fit)
# Out:
# Cross-validation classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       351
#            1       1.00      1.00      1.00       288
#            2       1.00      1.00      1.00       208
#
#     accuracy                           1.00       847
#    macro avg       1.00      1.00      1.00       847
# weighted avg       1.00      1.00      1.00       847
#
# Test classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        78
#            1       0.99      1.00      0.99        86
#            2       0.98      0.98      0.98        48
#
#     accuracy                           0.99       212
#    macro avg       0.99      0.99      0.99       212
# weighted avg       0.99      0.99      0.99       212
# alt.Chart(...)

# %%
# Get the cross-validation results
results = grid_search.cv_results_

# Extract hyperparameter values and F1-scores
n_estimators_values = results['param_n_estimators']
max_depth_values = results['param_max_depth'].data.astype(str)
f1_scores = results['mean_test_score']

# print(len(n_estimators_values))
# print(len(max_depth_values))
# print(len(f1_scores))

# Create DataFrame from GridSearchCV results
gridsearch = pd.DataFrame({
    'n_estimators': n_estimators_values,
    'max_depth': max_depth_values,
    'F1 Score': f1_scores
})

gridsearch.head()
# Out:
#    n_estimators max_depth  F1 Score
# 0             5      None  0.998717
# 1            10      None  0.997334
# 2            25      None  0.997334
# 3            50      None  0.997334
# 4            75      None  0.997334

# %%
# plotting F1 score vs number of trees by tree depth
max_depth_order = ['1', '5', '10', '15', '20', 'None']

alt.Chart(gridsearch).mark_line().encode(
    x = alt.X('n_estimators:O', axis=alt.Axis(grid=True)),
    y = alt.Y('F1 Score:Q', scale=alt.Scale(domain=[0.40, 1.00])),
    color=alt.Color('max_depth:N', sort=max_depth_order)
).properties(
    height=150, 
    width=150
).facet(
    column=alt.Column('max_depth:N', sort=max_depth_order)
)
# Out:
# alt.FacetChart(...)

# %%
# plotting F1 score vs tree depth by number of trees
max_depth_order = ['1', '5', '10', '15', '20', 'None']

alt.Chart(gridsearch).mark_line().encode(
    x = alt.X('max_depth:N', axis=alt.Axis(grid=True), sort=max_depth_order),
    y = alt.Y('F1 Score:Q', scale=alt.Scale(domain=[0.50, 1.00])),
    color=alt.Color('n_estimators:O')
).properties(
    height=150, 
    width=150
).facet(
    column=alt.Column('n_estimators:O')
)
# Out:
# alt.FacetChart(...)
